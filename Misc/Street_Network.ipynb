# %%
import os, geopandas as gpd, networkx as nx
from shapely.geometry import Point, MultiLineString, LineString
from networkx import Graph, connected_components
import warnings
warnings.filterwarnings("ignore")

# %%
subdivision_dataset = gpd.read_file("../../../../../Edited Subdivisions Zurikanen Erfan 4-20=2025/subs_plus_new/sub.gdb",layer='subs_new_combined_4_18_2025_2010_2023')
source_edges_path = "../../../Data/Original_dataset/Archive/centerlinemeck_10_8/"
source_edges = gpd.read_file("../../../Data/Original_dataset/Archive/centerlinemeck_10_8/edges_version_2.shp")

# %%
#1 Node extraction

nodes_version_1_path = os.path.join(source_edges_path, "nodes.shp")

if __name__ == "__main__":

    # Create an empty list to store the endpoint coordinates
    endpoint_coords = []
    # Iterate through the street network and find endpoint coordinates
    node_id = 0; node_id_mapping = {}
    
   
    # Iterate through the edges and find the end points coordinates
    for index, row in source_edges.iterrows():
        geometry = row['geometry']
        if geometry.geom_type == 'MultiLineString':
             print(f"Row {index} has a MultiLineString; using the first LineString component.")
             continue           
        start_point = Point(geometry.coords[0])
        end_point = Point(geometry.coords[-1])

        # Add start and end node ids to the edge GeoDataFrame
        if start_point.coords[0] not in node_id_mapping:
            endpoint_coords.append({'id': node_id, 'geometry': start_point})
            node_id_mapping[start_point.coords[0]] = node_id
            start_node_id = node_id
            node_id += 1
        else:
            start_node_id = node_id_mapping[start_point.coords[0]]

        if end_point.coords[0] not in node_id_mapping:
            endpoint_coords.append({'id': node_id, 'geometry': end_point})
            node_id_mapping[end_point.coords[0]] = node_id
            end_node_id = node_id
            node_id += 1
        else:
            end_node_id = node_id_mapping[end_point.coords[0]]

        #Adding corresponding start and end node's ID to each edge
        source_edges.at[index, 'start_node'] = start_node_id
        source_edges.at[index, 'end_node'] = end_node_id


        print(f"The edge {index} has been merged successfully!")

 
    # Create a GeoDataFrame from the endpoint coordinates
    source_nodes_gdf = gpd.GeoDataFrame(endpoint_coords, crs=source_edges.crs)
    source_nodes_gdf['x'] = source_nodes_gdf['geometry'].x; source_nodes_gdf['y'] = source_nodes_gdf['geometry'].y; source_nodes_gdf["osmid"] = source_nodes_gdf["id"].astype("int")
    source_nodes_gdf.set_index('id', inplace=True)  # Set 'id' column as index

    # Save the node shapefile and indexed edges
    source_nodes_gdf.to_file(nodes_version_1_path)
    
    #Exporting updated edges
    source_edges_path_updated = os.path.join(source_edges_path, "edges_updated.shp")
    source_edges.to_file(source_edges_path_updated)

    print(f"The nodes of the source edgee has been created successfully!")
# Out:
# The edge 0 has been merged successfully!
# The edge 1 has been merged successfully!
# The edge 2 has been merged successfully!
# The edge 3 has been merged successfully!
# The edge 4 has been merged successfully!
# The edge 5 has been merged successfully!
# The edge 6 has been merged successfully!
# The edge 7 has been merged successfully!
# The edge 8 has been merged successfully!
# The edge 9 has been merged successfully!
# The edge 10 has been merged successfully!
# The edge 11 has been merged successfully!
# The edge 12 has been merged successfully!
# The edge 13 has been merged successfully!
# The edge 14 has been merged successfully!
# The edge 15 has been merged successfully!
# The edge 16 has been merged successfully!
# The edge 17 has been merged successfully!
# The edge 18 has been merged successfully!
# The edge 19 has been merged successfully!
# The edge 20 has been merged successfully!
# The edge 21 has been merged successfully!
# The edge 22 has been merged successfully!
# The edge 23 has been merged successfully!
# The edge 24 has been merged successfully!
# The edge 25 has been merged successfully!
# The edge 26 has been merged successfully!
# The edge 27 has been merged successfully!
# The edge 28 has been merged successfully!
# The edge 29 has been merged successfully!
# The edge 30 has been merged successfully!
# The edge 31 has been merged successfully!
# The edge 32 has been merged successfully!
# The edge 33 has been merged successfully!
# The edge 34 has been merged successfully!
# The edge 35 has been merged successfully!
# The edge 36 has been merged successfully!
# The edge 37 has been merged successfully!
# The edge 38 has been merged successfully!
# The edge 39 has been merged successfully!
# The edge 40 has been merged successfully!
# The edge 41 has been merged successfully!
# The edge 42 has been merged successfully!
# The edge 43 has been merged successfully!
# The edge 44 has been merged successfully!
# The edge 45 has been merged successfully!
# The edge 46 has been merged successfully!
# The edge 47 has been merged successfully!
# The edge 48 has been merged successfully!
# The edge 49 has been merged successfully!
# The edge 50 has been merged successfully!
# The edge 51 has been merged successfully!
# The edge 52 has been merged successfully!
# The edge 53 has been merged successfully!
# The edge 54 has been merged successfully!
# The edge 55 has been merged successfully!
# The edge 56 has been merged successfully!
# The edge 57 has been merged successfully!
# The edge 58 has been merged successfully!
# The edge 59 has been merged successfully!
# The edge 60 has been merged successfully!
# The edge 61 has been merged successfully!
# The edge 62 has been merged successfully!
# The edge 63 has been merged successfully!
# The edge 64 has been merged successfully!
# The edge 65 has been merged successfully!
# The edge 66 has been merged successfully!
# The edge 67 has been merged successfully!
# The edge 68 has been merged successfully!
# The edge 69 has been merged successfully!
# The edge 70 has been merged successfully!
# The edge 71 has been merged successfully!
# The edge 72 has been merged successfully!
# The edge 73 has been merged successfully!
# The edge 74 has been merged successfully!
# The edge 75 has been merged successfully!
# The edge 76 has been merged successfully!
# The edge 77 has been merged successfully!
# The edge 78 has been merged successfully!
# The edge 79 has been merged successfully!
# The edge 80 has been merged successfully!
# The edge 81 has been merged successfully!
# The edge 82 has been merged successfully!
# The edge 83 has been merged successfully!
# The edge 84 has been merged successfully!
# The edge 85 has been merged successfully!
# The edge 86 has been merged successfully!
# The edge 87 has been merged successfully!
# The edge 88 has been merged successfully!
# The edge 89 has been merged successfully!
# The edge 90 has been merged successfully!
# The edge 91 has been merged successfully!
# The edge 92 has been merged successfully!
# The edge 93 has been merged successfully!
# The edge 94 has been merged successfully!
# The edge 95 has been merged successfully!
# The edge 96 has been merged successfully!
# The edge 97 has been merged successfully!
# The edge 98 has been merged successfully!
# The edge 99 has been merged successfully!
# The edge 100 has been merged successfully!
# The edge 101 has been merged successfully!
# The edge 102 has been merged successfully!
# The edge 103 has been merged successfully!
# The edge 104 has been merged successfully!
# The edge 105 has been merged successfully!
# The edge 106 has been merged successfully!
# The edge 107 has been merged successfully!
# The edge 108 has been merged successfully!
# The edge 109 has been merged successfully!
# The edge 110 has been merged successfully!
# The edge 111 has been merged successfully!
# The edge 112 has been merged successfully!
# The edge 113 has been merged successfully!
# The edge 114 has been merged successfully!
# The edge 115 has been merged successfully!
# The edge 116 has been merged successfully!
# The edge 117 has been merged successfully!
# The edge 118 has been merged successfully!
# The edge 119 has been merged successfully!
# The edge 120 has been merged successfully!
# The edge 121 has been merged successfully!
# The edge 122 has been merged successfully!
# The edge 123 has been merged successfully!
# The edge 124 has been merged successfully!
# The edge 125 has been merged successfully!
# The edge 126 has been merged successfully!
# The edge 127 has been merged successfully!
# The edge 128 has been merged successfully!
# The edge 129 has been merged successfully!
# The edge 130 has been merged successfully!
# The edge 131 has been merged successfully!
# The edge 132 has been merged successfully!
# The edge 133 has been merged successfully!
# The edge 134 has been merged successfully!
# The edge 135 has been merged successfully!
# The edge 136 has been merged successfully!
# The edge 137 has been merged successfully!
# The edge 138 has been merged successfully!
# The edge 139 has been merged successfully!
# The edge 140 has been merged successfully!
# The edge 141 has been merged successfully!
# The edge 142 has been merged successfully!
# The edge 143 has been merged successfully!
# The edge 144 has been merged successfully!
# The edge 145 has been merged successfully!
# The edge 146 has been merged successfully!
# The edge 147 has been merged successfully!
# The edge 148 has been merged successfully!
# The edge 149 has been merged successfully!
# The edge 150 has been merged successfully!
# The edge 151 has been merged successfully!
# The edge 152 has been merged successfully!
# The edge 153 has been merged successfully!
# The edge 154 has been merged successfully!
# The edge 155 has been merged successfully!
# The edge 156 has been merged successfully!
# The edge 157 has been merged successfully!
# The edge 158 has been merged successfully!
# The edge 159 has been merged successfully!
# The edge 160 has been merged successfully!
# The edge 161 has been merged successfully!
# The edge 162 has been merged successfully!
# The edge 163 has been merged successfully!
# The edge 164 has been merged successfully!
# The edge 165 has been merged successfully!
# The edge 166 has been merged successfully!
# The edge 167 has been merged successfully!
# The edge 168 has been merged successfully!
# The edge 169 has been merged successfully!
# The edge 170 has been merged successfully!
# The edge 171 has been merged successfully!
# The edge 172 has been merged successfully!
# The edge 173 has been merged successfully!
# The edge 174 has been merged successfully!
# The edge 175 has been merged successfully!
# The edge 176 has been merged successfully!
# The edge 177 has been merged successfully!
# The edge 178 has been merged successfully!
# The edge 179 has been merged successfully!
# The edge 180 has been merged successfully!
# The edge 181 has been merged successfully!
# The edge 182 has been merged successfully!
# The edge 183 has been merged successfully!
# The edge 184 has been merged successfully!
# The edge 185 has been merged successfully!
# The edge 186 has been merged successfully!
# The edge 187 has been merged successfully!
# The edge 188 has been merged successfully!
# The edge 189 has been merged successfully!
# The edge 190 has been merged successfully!
# The edge 191 has been merged successfully!
# The edge 192 has been merged successfully!
# The edge 193 has been merged successfully!
# The edge 194 has been merged successfully!
# The edge 195 has been merged successfully!
# The edge 196 has been merged successfully!
# The edge 197 has been merged successfully!
# The edge 198 has been merged successfully!
# The edge 199 has been merged successfully!
# The edge 200 has been merged successfully!
# The edge 201 has been merged successfully!
# The edge 202 has been merged successfully!
# The edge 203 has been merged successfully!
# The edge 204 has been merged successfully!
# The edge 205 has been merged successfully!
# The edge 206 has been merged successfully!
# The edge 207 has been merged successfully!
# The edge 208 has been merged successfully!
# The edge 209 has been merged successfully!
# The edge 210 has been merged successfully!
# The edge 211 has been merged successfully!
# The edge 212 has been merged successfully!
# The edge 213 has been merged successfully!
# The edge 214 has been merged successfully!
# The edge 215 has been merged successfully!
# The edge 216 has been merged successfully!
# The edge 217 has been merged successfully!
# The edge 218 has been merged successfully!
# The edge 219 has been merged successfully!
# The edge 220 has been merged successfully!
# The edge 221 has been merged successfully!
# The edge 222 has been merged successfully!
# The edge 223 has been merged successfully!
# The edge 224 has been merged successfully!
# The edge 225 has been merged successfully!
# The edge 226 has been merged successfully!
# The edge 227 has been merged successfully!
# The edge 228 has been merged successfully!
# The edge 229 has been merged successfully!
# The edge 230 has been merged successfully!
# The edge 231 has been merged successfully!
# The edge 232 has been merged successfully!
# The edge 233 has been merged successfully!
# The edge 234 has been merged successfully!
# The edge 235 has been merged successfully!
# The edge 236 has been merged successfully!
# The edge 237 has been merged successfully!
# The edge 238 has been merged successfully!
# The edge 239 has been merged successfully!
# The edge 240 has been merged successfully!
# The edge 241 has been merged successfully!
# The edge 242 has been merged successfully!
# The edge 243 has been merged successfully!
# The edge 244 has been merged successfully!
# The edge 245 has been merged successfully!
# The edge 246 has been merged successfully!
# The edge 247 has been merged successfully!
# The edge 248 has been merged successfully!
# The edge 249 has been merged successfully!
# The edge 250 has been merged successfully!
# The edge 251 has been merged successfully!
# The edge 252 has been merged successfully!
# The edge 253 has been merged successfully!
# The edge 254 has been merged successfully!
# The edge 255 has been merged successfully!
# The edge 256 has been merged successfully!
# The edge 257 has been merged successfully!
# The edge 258 has been merged successfully!
# The edge 259 has been merged successfully!
# The edge 260 has been merged successfully!
# The edge 261 has been merged successfully!
# The edge 262 has been merged successfully!
# The edge 263 has been merged successfully!
# The edge 264 has been merged successfully!
# The edge 265 has been merged successfully!
# The edge 266 has been merged successfully!
# The edge 267 has been merged successfully!
# The edge 268 has been merged successfully!
# The edge 269 has been merged successfully!
# The edge 270 has been merged successfully!
# The edge 271 has been merged successfully!
# The edge 272 has been merged successfully!
# The edge 273 has been merged successfully!
# The edge 274 has been merged successfully!
# The edge 275 has been merged successfully!
# The edge 276 has been merged successfully!
# The edge 277 has been merged successfully!
# The edge 278 has been merged successfully!
# The edge 279 has been merged successfully!
# The edge 280 has been merged successfully!
# The edge 281 has been merged successfully!
# The edge 282 has been merged successfully!
# The edge 283 has been merged successfully!
# The edge 284 has been merged successfully!
# The edge 285 has been merged successfully!
# The edge 286 has been merged successfully!
# The edge 287 has been merged successfully!
# The edge 288 has been merged successfully!
# The edge 289 has been merged successfully!
# The edge 290 has been merged successfully!
# The edge 291 has been merged successfully!
# The edge 292 has been merged successfully!
# The edge 293 has been merged successfully!
# The edge 294 has been merged successfully!
# The edge 295 has been merged successfully!
# The edge 296 has been merged successfully!
# The edge 297 has been merged successfully!
# The edge 298 has been merged successfully!
# The edge 299 has been merged successfully!
# The edge 300 has been merged successfully!
# The edge 301 has been merged successfully!
# The edge 302 has been merged successfully!
# The edge 303 has been merged successfully!
# The edge 304 has been merged successfully!
# The edge 305 has been merged successfully!
# The edge 306 has been merged successfully!
# The edge 307 has been merged successfully!
# The edge 308 has been merged successfully!
# The edge 309 has been merged successfully!
# The edge 310 has been merged successfully!
# The edge 311 has been merged successfully!
# The edge 312 has been merged successfully!
# The edge 313 has been merged successfully!
# The edge 314 has been merged successfully!
# The edge 315 has been merged successfully!
# The edge 316 has been merged successfully!
# The edge 317 has been merged successfully!
# The edge 318 has been merged successfully!
# The edge 319 has been merged successfully!
# The edge 320 has been merged successfully!
# The edge 321 has been merged successfully!
# The edge 322 has been merged successfully!
# The edge 323 has been merged successfully!
# The edge 324 has been merged successfully!
# The edge 325 has been merged successfully!
# The edge 326 has been merged successfully!
# The edge 327 has been merged successfully!
# The edge 328 has been merged successfully!
# The edge 329 has been merged successfully!
# The edge 330 has been merged successfully!
# The edge 331 has been merged successfully!
# The edge 332 has been merged successfully!
# The edge 333 has been merged successfully!
# The edge 334 has been merged successfully!
# The edge 335 has been merged successfully!
# The edge 336 has been merged successfully!
# The edge 337 has been merged successfully!
# The edge 338 has been merged successfully!
# The edge 339 has been merged successfully!
# The edge 340 has been merged successfully!
# The edge 341 has been merged successfully!
# The edge 342 has been merged successfully!
# The edge 343 has been merged successfully!
# The edge 344 has been merged successfully!
# The edge 345 has been merged successfully!
# The edge 346 has been merged successfully!
# The edge 347 has been merged successfully!
# The edge 348 has been merged successfully!
# The edge 349 has been merged successfully!
# The edge 350 has been merged successfully!
# The edge 351 has been merged successfully!
# The edge 352 has been merged successfully!
# The edge 353 has been merged successfully!
# The edge 354 has been merged successfully!
# The edge 355 has been merged successfully!
# The edge 356 has been merged successfully!
# The edge 357 has been merged successfully!
# The edge 358 has been merged successfully!
# The edge 359 has been merged successfully!
# The edge 360 has been merged successfully!
# The edge 361 has been merged successfully!
# The edge 362 has been merged successfully!
# The edge 363 has been merged successfully!
# The edge 364 has been merged successfully!
# The edge 365 has been merged successfully!
# The edge 366 has been merged successfully!
# The edge 367 has been merged successfully!
# The edge 368 has been merged successfully!
# The edge 369 has been merged successfully!
# The edge 370 has been merged successfully!
# The edge 371 has been merged successfully!
# The edge 372 has been merged successfully!
# The edge 373 has been merged successfully!
# The edge 374 has been merged successfully!
# The edge 375 has been merged successfully!
# The edge 376 has been merged successfully!
# The edge 377 has been merged successfully!
# The edge 378 has been merged successfully!
# The edge 379 has been merged successfully!
# The edge 380 has been merged successfully!
# The edge 381 has been merged successfully!
# The edge 382 has been merged successfully!
# The edge 383 has been merged successfully!
# The edge 384 has been merged successfully!
# The edge 385 has been merged successfully!
# The edge 386 has been merged successfully!
# The edge 387 has been merged successfully!
# The edge 388 has been merged successfully!
# The edge 389 has been merged successfully!
# The edge 390 has been merged successfully!
# The edge 391 has been merged successfully!
# The edge 392 has been merged successfully!
# The edge 393 has been merged successfully!
# The edge 394 has been merged successfully!
# The edge 395 has been merged successfully!
# The edge 396 has been merged successfully!
# The edge 397 has been merged successfully!
# The edge 398 has been merged successfully!
# The edge 399 has been merged successfully!
# The edge 400 has been merged successfully!
# The edge 401 has been merged successfully!
# The edge 402 has been merged successfully!
# The edge 403 has been merged successfully!
# The edge 404 has been merged successfully!
# The edge 405 has been merged successfully!
# The edge 406 has been merged successfully!
# The edge 407 has been merged successfully!
# The edge 408 has been merged successfully!
# The edge 409 has been merged successfully!
# The edge 410 has been merged successfully!
# The edge 411 has been merged successfully!
# The edge 412 has been merged successfully!
# The edge 413 has been merged successfully!
# The edge 414 has been merged successfully!
# The edge 415 has been merged successfully!
# The edge 416 has been merged successfully!
# The edge 417 has been merged successfully!
# The edge 418 has been merged successfully!
# The edge 419 has been merged successfully!
# The edge 420 has been merged successfully!
# The edge 421 has been merged successfully!
# The edge 422 has been merged successfully!
# The edge 423 has been merged successfully!
# The edge 424 has been merged successfully!
# The edge 425 has been merged successfully!
# The edge 426 has been merged successfully!
# The edge 427 has been merged successfully!
# The edge 428 has been merged successfully!
# The edge 429 has been merged successfully!
# The edge 430 has been merged successfully!
# The edge 431 has been merged successfully!
# The edge 432 has been merged successfully!
# The edge 433 has been merged successfully!
# The edge 434 has been merged successfully!
# The edge 435 has been merged successfully!
# The edge 436 has been merged successfully!
# The edge 437 has been merged successfully!
# The edge 438 has been merged successfully!
# The edge 439 has been merged successfully!
# The edge 440 has been merged successfully!
# The edge 441 has been merged successfully!
# The edge 442 has been merged successfully!
# The edge 443 has been merged successfully!
# The edge 444 has been merged successfully!
# The edge 445 has been merged successfully!
# The edge 446 has been merged successfully!
# The edge 447 has been merged successfully!
# The edge 448 has been merged successfully!
# The edge 449 has been merged successfully!
# The edge 450 has been merged successfully!
# The edge 451 has been merged successfully!
# The edge 452 has been merged successfully!
# The edge 453 has been merged successfully!
# The edge 454 has been merged successfully!
# The edge 455 has been merged successfully!
# The edge 456 has been merged successfully!
# The edge 457 has been merged successfully!
# The edge 458 has been merged successfully!
# The edge 459 has been merged successfully!
# The edge 460 has been merged successfully!
# The edge 461 has been merged successfully!
# The edge 462 has been merged successfully!
# The edge 463 has been merged successfully!
# The edge 464 has been merged successfully!
# The edge 465 has been merged successfully!
# The edge 466 has been merged successfully!
# The edge 467 has been merged successfully!
# The edge 468 has been merged successfully!
# The edge 469 has been merged successfully!
# The edge 470 has been merged successfully!
# The edge 471 has been merged successfully!
# The edge 472 has been merged successfully!
# The edge 473 has been merged successfully!
# The edge 474 has been merged successfully!
# The edge 475 has been merged successfully!
# The edge 476 has been merged successfully!
# The edge 477 has been merged successfully!
# The edge 478 has been merged successfully!
# The edge 479 has been merged successfully!
# The edge 480 has been merged successfully!
# The edge 481 has been merged successfully!
# The edge 482 has been merged successfully!
# The edge 483 has been merged successfully!
# The edge 484 has been merged successfully!
# The edge 485 has been merged successfully!
# The edge 486 has been merged successfully!
# The edge 487 has been merged successfully!
# The edge 488 has been merged successfully!
# The edge 489 has been merged successfully!
# The edge 490 has been merged successfully!
# The edge 491 has been merged successfully!
# The edge 492 has been merged successfully!
# The edge 493 has been merged successfully!
# The edge 494 has been merged successfully!
# The edge 495 has been merged successfully!
# The edge 496 has been merged successfully!
# The edge 497 has been merged successfully!
# The edge 498 has been merged successfully!
# The edge 499 has been merged successfully!
# The edge 500 has been merged successfully!
# The edge 501 has been merged successfully!
# The edge 502 has been merged successfully!
# The edge 503 has been merged successfully!
# The edge 504 has been merged successfully!
# The edge 505 has been merged successfully!
# The edge 506 has been merged successfully!
# The edge 507 has been merged successfully!
# The edge 508 has been merged successfully!
# The edge 509 has been merged successfully!
# The edge 510 has been merged successfully!
# The edge 511 has been merged successfully!
# The edge 512 has been merged successfully!
# The edge 513 has been merged successfully!
# The edge 514 has been merged successfully!
# The edge 515 has been merged successfully!
# The edge 516 has been merged successfully!
# The edge 517 has been merged successfully!
# The edge 518 has been merged successfully!
# The edge 519 has been merged successfully!
# The edge 520 has been merged successfully!
# The edge 521 has been merged successfully!
# The edge 522 has been merged successfully!
# The edge 523 has been merged successfully!
# The edge 524 has been merged successfully!
# The edge 525 has been merged successfully!
# The edge 526 has been merged successfully!
# The edge 527 has been merged successfully!
# The edge 528 has been merged successfully!
# The edge 529 has been merged successfully!
# The edge 530 has been merged successfully!
# The edge 531 has been merged successfully!
# The edge 532 has been merged successfully!
# The edge 533 has been merged successfully!
# The edge 534 has been merged successfully!
# The edge 535 has been merged successfully!
# The edge 536 has been merged successfully!
# The edge 537 has been merged successfully!
# The edge 538 has been merged successfully!
# The edge 539 has been merged successfully!
# The edge 540 has been merged successfully!
# The edge 541 has been merged successfully!
# The edge 542 has been merged successfully!
# The edge 543 has been merged successfully!
# The edge 544 has been merged successfully!
# The edge 545 has been merged successfully!
# The edge 546 has been merged successfully!
# The edge 547 has been merged successfully!
# The edge 548 has been merged successfully!
# The edge 549 has been merged successfully!
# The edge 550 has been merged successfully!
# The edge 551 has been merged successfully!
# The edge 552 has been merged successfully!
# The edge 553 has been merged successfully!
# The edge 554 has been merged successfully!
# The edge 555 has been merged successfully!
# The edge 556 has been merged successfully!
# The edge 557 has been merged successfully!
# The edge 558 has been merged successfully!
# The edge 559 has been merged successfully!
# The edge 560 has been merged successfully!
# The edge 561 has been merged successfully!
# The edge 562 has been merged successfully!
# The edge 563 has been merged successfully!
# The edge 564 has been merged successfully!
# The edge 565 has been merged successfully!
# The edge 566 has been merged successfully!
# The edge 567 has been merged successfully!
# The edge 568 has been merged successfully!
# The edge 569 has been merged successfully!
# The edge 570 has been merged successfully!
# The edge 571 has been merged successfully!
# The edge 572 has been merged successfully!
# The edge 573 has been merged successfully!
# The edge 574 has been merged successfully!
# The edge 575 has been merged successfully!
# The edge 576 has been merged successfully!
# The edge 577 has been merged successfully!
# The edge 578 has been merged successfully!
# The edge 579 has been merged successfully!
# The edge 580 has been merged successfully!
# The edge 581 has been merged successfully!
# The edge 582 has been merged successfully!
# The edge 583 has been merged successfully!
# The edge 584 has been merged successfully!
# The edge 585 has been merged successfully!
# The edge 586 has been merged successfully!
# The edge 587 has been merged successfully!
# The edge 588 has been merged successfully!
# The edge 589 has been merged successfully!
# The edge 590 has been merged successfully!
# The edge 591 has been merged successfully!
# The edge 592 has been merged successfully!
# The edge 593 has been merged successfully!
# The edge 594 has been merged successfully!
# The edge 595 has been merged successfully!
# The edge 596 has been merged successfully!
# The edge 597 has been merged successfully!
# The edge 598 has been merged successfully!
# The edge 599 has been merged successfully!
# The edge 600 has been merged successfully!
# The edge 601 has been merged successfully!
# The edge 602 has been merged successfully!
# The edge 603 has been merged successfully!
# The edge 604 has been merged successfully!
# The edge 605 has been merged successfully!
# The edge 606 has been merged successfully!
# The edge 607 has been merged successfully!
# The edge 608 has been merged successfully!
# The edge 609 has been merged successfully!
# The edge 610 has been merged successfully!
# The edge 611 has been merged successfully!
# The edge 612 has been merged successfully!
# The edge 613 has been merged successfully!
# The edge 614 has been merged successfully!
# The edge 615 has been merged successfully!
# The edge 616 has been merged successfully!
# The edge 617 has been merged successfully!
# The edge 618 has been merged successfully!
# The edge 619 has been merged successfully!
# The edge 620 has been merged successfully!
# The edge 621 has been merged successfully!
# The edge 622 has been merged successfully!
# The edge 623 has been merged successfully!
# The edge 624 has been merged successfully!
# The edge 625 has been merged successfully!
# The edge 626 has been merged successfully!
# The edge 627 has been merged successfully!
# The edge 628 has been merged successfully!
# The edge 629 has been merged successfully!
# The edge 630 has been merged successfully!
# The edge 631 has been merged successfully!
# The edge 632 has been merged successfully!
# The edge 633 has been merged successfully!
# The edge 634 has been merged successfully!
# The edge 635 has been merged successfully!
# The edge 636 has been merged successfully!
# The edge 637 has been merged successfully!
# The edge 638 has been merged successfully!
# The edge 639 has been merged successfully!
# The edge 640 has been merged successfully!
# The edge 641 has been merged successfully!
# The edge 642 has been merged successfully!
# The edge 643 has been merged successfully!
# The edge 644 has been merged successfully!
# The edge 645 has been merged successfully!
# The edge 646 has been merged successfully!
# The edge 647 has been merged successfully!
# The edge 648 has been merged successfully!
# The edge 649 has been merged successfully!
# The edge 650 has been merged successfully!
# The edge 651 has been merged successfully!
# The edge 652 has been merged successfully!
# The edge 653 has been merged successfully!
# The edge 654 has been merged successfully!
# The edge 655 has been merged successfully!
# The edge 656 has been merged successfully!
# The edge 657 has been merged successfully!
# The edge 658 has been merged successfully!
# The edge 659 has been merged successfully!
# The edge 660 has been merged successfully!
# The edge 661 has been merged successfully!
# The edge 662 has been merged successfully!
# The edge 663 has been merged successfully!
# The edge 664 has been merged successfully!
# The edge 665 has been merged successfully!
# The edge 666 has been merged successfully!
# The edge 667 has been merged successfully!
# The edge 668 has been merged successfully!
# The edge 669 has been merged successfully!
# The edge 670 has been merged successfully!
# The edge 671 has been merged successfully!
# The edge 672 has been merged successfully!
# The edge 673 has been merged successfully!
# The edge 674 has been merged successfully!
# The edge 675 has been merged successfully!
# The edge 676 has been merged successfully!
# The edge 677 has been merged successfully!
# The edge 678 has been merged successfully!
# The edge 679 has been merged successfully!
# The edge 680 has been merged successfully!
# The edge 681 has been merged successfully!
# The edge 682 has been merged successfully!
# The edge 683 has been merged successfully!
# The edge 684 has been merged successfully!
# The edge 685 has been merged successfully!
# The edge 686 has been merged successfully!
# The edge 687 has been merged successfully!
# The edge 688 has been merged successfully!
# The edge 689 has been merged successfully!
# The edge 690 has been merged successfully!
# The edge 691 has been merged successfully!
# The edge 692 has been merged successfully!
# The edge 693 has been merged successfully!
# The edge 694 has been merged successfully!
# The edge 695 has been merged successfully!
# The edge 696 has been merged successfully!
# The edge 697 has been merged successfully!
# The edge 698 has been merged successfully!
# The edge 699 has been merged successfully!
# The edge 700 has been merged successfully!
# The edge 701 has been merged successfully!
# The edge 702 has been merged successfully!
# The edge 703 has been merged successfully!
# The edge 704 has been merged successfully!
# The edge 705 has been merged successfully!
# The edge 706 has been merged successfully!
# The edge 707 has been merged successfully!
# The edge 708 has been merged successfully!
# The edge 709 has been merged successfully!
# The edge 710 has been merged successfully!
# The edge 711 has been merged successfully!
# The edge 712 has been merged successfully!
# The edge 713 has been merged successfully!
# The edge 714 has been merged successfully!
# The edge 715 has been merged successfully!
# The edge 716 has been merged successfully!
# The edge 717 has been merged successfully!
# The edge 718 has been merged successfully!
# The edge 719 has been merged successfully!
# The edge 720 has been merged successfully!
# The edge 721 has been merged successfully!
# The edge 722 has been merged successfully!
# The edge 723 has been merged successfully!
# The edge 724 has been merged successfully!
# The edge 725 has been merged successfully!
# The edge 726 has been merged successfully!
# The edge 727 has been merged successfully!
# The edge 728 has been merged successfully!
# The edge 729 has been merged successfully!
# The edge 730 has been merged successfully!
# The edge 731 has been merged successfully!
# The edge 732 has been merged successfully!
# The edge 733 has been merged successfully!
# The edge 734 has been merged successfully!
# The edge 735 has been merged successfully!
# The edge 736 has been merged successfully!
# The edge 737 has been merged successfully!
# The edge 738 has been merged successfully!
# The edge 739 has been merged successfully!
# The edge 740 has been merged successfully!
# The edge 741 has been merged successfully!
# The edge 742 has been merged successfully!
# The edge 743 has been merged successfully!
# The edge 744 has been merged successfully!
# The edge 745 has been merged successfully!
# The edge 746 has been merged successfully!
# The edge 747 has been merged successfully!
# The edge 748 has been merged successfully!
# The edge 749 has been merged successfully!
# The edge 750 has been merged successfully!
# The edge 751 has been merged successfully!
# The edge 752 has been merged successfully!
# The edge 753 has been merged successfully!
# The edge 754 has been merged successfully!
# The edge 755 has been merged successfully!
# The edge 756 has been merged successfully!
# The edge 757 has been merged successfully!
# The edge 758 has been merged successfully!
# The edge 759 has been merged successfully!
# The edge 760 has been merged successfully!
# The edge 761 has been merged successfully!
# The edge 762 has been merged successfully!
# The edge 763 has been merged successfully!
# The edge 764 has been merged successfully!
# The edge 765 has been merged successfully!
# The edge 766 has been merged successfully!
# The edge 767 has been merged successfully!
# The edge 768 has been merged successfully!
# The edge 769 has been merged successfully!
# The edge 770 has been merged successfully!
# The edge 771 has been merged successfully!
# The edge 772 has been merged successfully!
# The edge 773 has been merged successfully!
# The edge 774 has been merged successfully!
# The edge 775 has been merged successfully!
# The edge 776 has been merged successfully!
# The edge 777 has been merged successfully!
# The edge 778 has been merged successfully!
# The edge 779 has been merged successfully!
# The edge 780 has been merged successfully!
# The edge 781 has been merged successfully!
# The edge 782 has been merged successfully!
# The edge 783 has been merged successfully!
# The edge 784 has been merged successfully!
# The edge 785 has been merged successfully!
# The edge 786 has been merged successfully!
# The edge 787 has been merged successfully!
# The edge 788 has been merged successfully!
# The edge 789 has been merged successfully!
# The edge 790 has been merged successfully!
# The edge 791 has been merged successfully!
# The edge 792 has been merged successfully!
# The edge 793 has been merged successfully!
# The edge 794 has been merged successfully!
# The edge 795 has been merged successfully!
# The edge 796 has been merged successfully!
# The edge 797 has been merged successfully!
# The edge 798 has been merged successfully!
# The edge 799 has been merged successfully!
# The edge 800 has been merged successfully!
# The edge 801 has been merged successfully!
# The edge 802 has been merged successfully!
# The edge 803 has been merged successfully!
# The edge 804 has been merged successfully!
# The edge 805 has been merged successfully!
# The edge 806 has been merged successfully!
# The edge 807 has been merged successfully!
# The edge 808 has been merged successfully!
# The edge 809 has been merged successfully!
# The edge 810 has been merged successfully!
# The edge 811 has been merged successfully!
# The edge 812 has been merged successfully!
# The edge 813 has been merged successfully!
# The edge 814 has been merged successfully!
# The edge 815 has been merged successfully!
# The edge 816 has been merged successfully!
# The edge 817 has been merged successfully!
# The edge 818 has been merged successfully!
# The edge 819 has been merged successfully!
# The edge 820 has been merged successfully!
# The edge 821 has been merged successfully!
# The edge 822 has been merged successfully!
# The edge 823 has been merged successfully!
# The edge 824 has been merged successfully!
# The edge 825 has been merged successfully!
# The edge 826 has been merged successfully!
# The edge 827 has been merged successfully!
# The edge 828 has been merged successfully!
# The edge 829 has been merged successfully!
# The edge 830 has been merged successfully!
# The edge 831 has been merged successfully!
# The edge 832 has been merged successfully!
# The edge 833 has been merged successfully!
# The edge 834 has been merged successfully!
# The edge 835 has been merged successfully!
# The edge 836 has been merged successfully!
# The edge 837 has been merged successfully!
# The edge 838 has been merged successfully!
# The edge 839 has been merged successfully!
# The edge 840 has been merged successfully!
# The edge 841 has been merged successfully!
# The edge 842 has been merged successfully!
# The edge 843 has been merged successfully!
# The edge 844 has been merged successfully!
# The edge 845 has been merged successfully!
# The edge 846 has been merged successfully!
# The edge 847 has been merged successfully!
# The edge 848 has been merged successfully!
# The edge 849 has been merged successfully!
# The edge 850 has been merged successfully!
# The edge 851 has been merged successfully!
# The edge 852 has been merged successfully!
# The edge 853 has been merged successfully!
# The edge 854 has been merged successfully!
# The edge 855 has been merged successfully!
# The edge 856 has been merged successfully!
# The edge 857 has been merged successfully!
# The edge 858 has been merged successfully!
# The edge 859 has been merged successfully!
# The edge 860 has been merged successfully!
# The edge 861 has been merged successfully!
# The edge 862 has been merged successfully!
# The edge 863 has been merged successfully!
# The edge 864 has been merged successfully!
# The edge 865 has been merged successfully!
# The edge 866 has been merged successfully!
# The edge 867 has been merged successfully!
# The edge 868 has been merged successfully!
# The edge 869 has been merged successfully!
# The edge 870 has been merged successfully!
# The edge 871 has been merged successfully!
# The edge 872 has been merged successfully!
# The edge 873 has been merged successfully!
# The edge 874 has been merged successfully!
# The edge 875 has been merged successfully!
# The edge 876 has been merged successfully!
# The edge 877 has been merged successfully!
# The edge 878 has been merged successfully!
# The edge 879 has been merged successfully!
# The edge 880 has been merged successfully!
# The edge 881 has been merged successfully!
# The edge 882 has been merged successfully!
# The edge 883 has been merged successfully!
# The edge 884 has been merged successfully!
# The edge 885 has been merged successfully!
# The edge 886 has been merged successfully!
# The edge 887 has been merged successfully!
# The edge 888 has been merged successfully!
# The edge 889 has been merged successfully!
# The edge 890 has been merged successfully!
# The edge 891 has been merged successfully!
# The edge 892 has been merged successfully!
# The edge 893 has been merged successfully!
# The edge 894 has been merged successfully!
# The edge 895 has been merged successfully!
# The edge 896 has been merged successfully!
# The edge 897 has been merged successfully!
# The edge 898 has been merged successfully!
# The edge 899 has been merged successfully!
# The edge 900 has been merged successfully!
# The edge 901 has been merged successfully!
# The edge 902 has been merged successfully!
# The edge 903 has been merged successfully!
# The edge 904 has been merged successfully!
# The edge 905 has been merged successfully!
# The edge 906 has been merged successfully!
# The edge 907 has been merged successfully!
# The edge 908 has been merged successfully!
# The edge 909 has been merged successfully!
# The edge 910 has been merged successfully!
# The edge 911 has been merged successfully!
# The edge 912 has been merged successfully!
# The edge 913 has been merged successfully!
# The edge 914 has been merged successfully!
# The edge 915 has been merged successfully!
# The edge 916 has been merged successfully!
# The edge 917 has been merged successfully!
# The edge 918 has been merged successfully!
# The edge 919 has been merged successfully!
# The edge 920 has been merged successfully!
# The edge 921 has been merged successfully!
# The edge 922 has been merged successfully!
# The edge 923 has been merged successfully!
# The edge 924 has been merged successfully!
# The edge 925 has been merged successfully!
# The edge 926 has been merged successfully!
# The edge 927 has been merged successfully!
# The edge 928 has been merged successfully!
# The edge 929 has been merged successfully!
# The edge 930 has been merged successfully!
# The edge 931 has been merged successfully!
# The edge 932 has been merged successfully!
# The edge 933 has been merged successfully!
# The edge 934 has been merged successfully!
# The edge 935 has been merged successfully!
# The edge 936 has been merged successfully!
# The edge 937 has been merged successfully!
# The edge 938 has been merged successfully!
# The edge 939 has been merged successfully!
# The edge 940 has been merged successfully!
# The edge 941 has been merged successfully!
# The edge 942 has been merged successfully!
# The edge 943 has been merged successfully!
# The edge 944 has been merged successfully!
# The edge 945 has been merged successfully!
# The edge 946 has been merged successfully!
# The edge 947 has been merged successfully!
# The edge 948 has been merged successfully!
# The edge 949 has been merged successfully!
# The edge 950 has been merged successfully!
# The edge 951 has been merged successfully!
# The edge 952 has been merged successfully!
# The edge 953 has been merged successfully!
# The edge 954 has been merged successfully!
# The edge 955 has been merged successfully!
# The edge 956 has been merged successfully!
# The edge 957 has been merged successfully!
# The edge 958 has been merged successfully!
# The edge 959 has been merged successfully!
# The edge 960 has been merged successfully!
# The edge 961 has been merged successfully!
# The edge 962 has been merged successfully!
# The edge 963 has been merged successfully!
# The edge 964 has been merged successfully!
# The edge 965 has been merged successfully!
# The edge 966 has been merged successfully!
# The edge 967 has been merged successfully!
# The edge 968 has been merged successfully!
# The edge 969 has been merged successfully!
# The edge 970 has been merged successfully!
# The edge 971 has been merged successfully!
# The edge 972 has been merged successfully!
# The edge 973 has been merged successfully!
# The edge 974 has been merged successfully!
# The edge 975 has been merged successfully!
# The edge 976 has been merged successfully!
# The edge 977 has been merged successfully!
# The edge 978 has been merged successfully!
# The edge 979 has been merged successfully!
# The edge 980 has been merged successfully!
# The edge 981 has been merged successfully!
# The edge 982 has been merged successfully!
# The edge 983 has been merged successfully!
# The edge 984 has been merged successfully!
# The edge 985 has been merged successfully!
# The edge 986 has been merged successfully!
# The edge 987 has been merged successfully!
# The edge 988 has been merged successfully!
# The edge 989 has been merged successfully!
# The edge 990 has been merged successfully!
# The edge 991 has been merged successfully!
# The edge 992 has been merged successfully!
# The edge 993 has been merged successfully!
# The edge 994 has been merged successfully!
# The edge 995 has been merged successfully!
# The edge 996 has been merged successfully!
# The edge 997 has been merged successfully!
# The edge 998 has been merged successfully!
# The edge 999 has been merged successfully!
# The edge 1000 has been merged successfully!
# The edge 1001 has been merged successfully!
# The edge 1002 has been merged successfully!
# The edge 1003 has been merged successfully!
# The edge 1004 has been merged successfully!
# The edge 1005 has been merged successfully!
# The edge 1006 has been merged successfully!
# The edge 1007 has been merged successfully!
# The edge 1008 has been merged successfully!
# The edge 1009 has been merged successfully!
# The edge 1010 has been merged successfully!
# The edge 1011 has been merged successfully!
# The edge 1012 has been merged successfully!
# The edge 1013 has been merged successfully!
# The edge 1014 has been merged successfully!
# The edge 1015 has been merged successfully!
# The edge 1016 has been merged successfully!
# The edge 1017 has been merged successfully!
# The edge 1018 has been merged successfully!
# The edge 1019 has been merged successfully!
# The edge 1020 has been merged successfully!
# The edge 1021 has been merged successfully!
# The edge 1022 has been merged successfully!
# The edge 1023 has been merged successfully!
# The edge 1024 has been merged successfully!
# The edge 1025 has been merged successfully!
# The edge 1026 has been merged successfully!
# The edge 1027 has been merged successfully!
# The edge 1028 has been merged successfully!
# The edge 1029 has been merged successfully!
# The edge 1030 has been merged successfully!
# The edge 1031 has been merged successfully!
# The edge 1032 has been merged successfully!
# The edge 1033 has been merged successfully!
# The edge 1034 has been merged successfully!
# The edge 1035 has been merged successfully!
# The edge 1036 has been merged successfully!
# The edge 1037 has been merged successfully!
# The edge 1038 has been merged successfully!
# The edge 1039 has been merged successfully!
# The edge 1040 has been merged successfully!
# The edge 1041 has been merged successfully!
# The edge 1042 has been merged successfully!
# The edge 1043 has been merged successfully!
# The edge 1044 has been merged successfully!
# The edge 1045 has been merged successfully!
# The edge 1046 has been merged successfully!
# The edge 1047 has been merged successfully!
# The edge 1048 has been merged successfully!
# The edge 1049 has been merged successfully!
# The edge 1050 has been merged successfully!
# The edge 1051 has been merged successfully!
# The edge 1052 has been merged successfully!
# The edge 1053 has been merged successfully!
# The edge 1054 has been merged successfully!
# The edge 1055 has been merged successfully!
# The edge 1056 has been merged successfully!
# The edge 1057 has been merged successfully!
# The edge 1058 has been merged successfully!
# The edge 1059 has been merged successfully!
# The edge 1060 has been merged successfully!
# The edge 1061 has been merged successfully!
# The edge 1062 has been merged successfully!
# The edge 1063 has been merged successfully!
# The edge 1064 has been merged successfully!
# The edge 1065 has been merged successfully!
# The edge 1066 has been merged successfully!
# The edge 1067 has been merged successfully!
# The edge 1068 has been merged successfully!
# The edge 1069 has been merged successfully!
# The edge 1070 has been merged successfully!
# The edge 1071 has been merged successfully!
# The edge 1072 has been merged successfully!
# The edge 1073 has been merged successfully!
# The edge 1074 has been merged successfully!
# The edge 1075 has been merged successfully!
# The edge 1076 has been merged successfully!
# The edge 1077 has been merged successfully!
# The edge 1078 has been merged successfully!
# The edge 1079 has been merged successfully!
# The edge 1080 has been merged successfully!
# The edge 1081 has been merged successfully!
# The edge 1082 has been merged successfully!
# The edge 1083 has been merged successfully!
# The edge 1084 has been merged successfully!
# The edge 1085 has been merged successfully!
# The edge 1086 has been merged successfully!
# The edge 1087 has been merged successfully!
# The edge 1088 has been merged successfully!
# The edge 1089 has been merged successfully!
# The edge 1090 has been merged successfully!
# The edge 1091 has been merged successfully!
# The edge 1092 has been merged successfully!
# The edge 1093 has been merged successfully!
# The edge 1094 has been merged successfully!
# The edge 1095 has been merged successfully!
# The edge 1096 has been merged successfully!
# The edge 1097 has been merged successfully!
# The edge 1098 has been merged successfully!
# The edge 1099 has been merged successfully!
# The edge 1100 has been merged successfully!
# The edge 1101 has been merged successfully!
# The edge 1102 has been merged successfully!
# The edge 1103 has been merged successfully!
# The edge 1104 has been merged successfully!
# The edge 1105 has been merged successfully!
# The edge 1106 has been merged successfully!
# The edge 1107 has been merged successfully!
# The edge 1108 has been merged successfully!
# The edge 1109 has been merged successfully!
# The edge 1110 has been merged successfully!
# The edge 1111 has been merged successfully!
# The edge 1112 has been merged successfully!
# The edge 1113 has been merged successfully!
# The edge 1114 has been merged successfully!
# The edge 1115 has been merged successfully!
# ...
# The edge 53474 has been merged successfully!
# The edge 53475 has been merged successfully!
# The edge 53476 has been merged successfully!
# The edge 53477 has been merged successfully!
# The edge 53478 has been merged successfully!
# The edge 53479 has been merged successfully!
# The edge 53480 has been merged successfully!
# The edge 53481 has been merged successfully!
# The edge 53482 has been merged successfully!
# The edge 53483 has been merged successfully!
# The edge 53484 has been merged successfully!
# The edge 53485 has been merged successfully!
# The edge 53486 has been merged successfully!
# The edge 53487 has been merged successfully!
# The edge 53488 has been merged successfully!
# The edge 53489 has been merged successfully!
# The edge 53490 has been merged successfully!
# The edge 53491 has been merged successfully!
# The edge 53492 has been merged successfully!
# The edge 53493 has been merged successfully!
# The edge 53494 has been merged successfully!
# The edge 53495 has been merged successfully!
# The edge 53496 has been merged successfully!
# The edge 53497 has been merged successfully!
# The edge 53498 has been merged successfully!
# The edge 53499 has been merged successfully!
# The edge 53500 has been merged successfully!
# The edge 53501 has been merged successfully!
# The edge 53502 has been merged successfully!
# The edge 53503 has been merged successfully!
# The edge 53504 has been merged successfully!
# The edge 53505 has been merged successfully!
# The edge 53506 has been merged successfully!
# The edge 53507 has been merged successfully!
# The edge 53508 has been merged successfully!
# The edge 53509 has been merged successfully!
# The edge 53510 has been merged successfully!
# The edge 53511 has been merged successfully!
# The edge 53512 has been merged successfully!
# The edge 53513 has been merged successfully!
# The edge 53514 has been merged successfully!
# The edge 53515 has been merged successfully!
# The edge 53516 has been merged successfully!
# The edge 53517 has been merged successfully!
# The edge 53518 has been merged successfully!
# The edge 53519 has been merged successfully!
# The edge 53520 has been merged successfully!
# The edge 53521 has been merged successfully!
# The edge 53522 has been merged successfully!
# The edge 53523 has been merged successfully!
# The edge 53524 has been merged successfully!
# The edge 53525 has been merged successfully!
# The edge 53526 has been merged successfully!
# The edge 53527 has been merged successfully!
# The edge 53528 has been merged successfully!
# The edge 53529 has been merged successfully!
# The edge 53530 has been merged successfully!
# The edge 53531 has been merged successfully!
# The edge 53532 has been merged successfully!
# The edge 53533 has been merged successfully!
# The edge 53534 has been merged successfully!
# The edge 53535 has been merged successfully!
# The edge 53536 has been merged successfully!
# The edge 53537 has been merged successfully!
# The edge 53538 has been merged successfully!
# The edge 53539 has been merged successfully!
# The edge 53540 has been merged successfully!
# The edge 53541 has been merged successfully!
# The edge 53542 has been merged successfully!
# The edge 53543 has been merged successfully!
# The edge 53544 has been merged successfully!
# The edge 53545 has been merged successfully!
# The edge 53546 has been merged successfully!
# The edge 53547 has been merged successfully!
# The edge 53548 has been merged successfully!
# The edge 53549 has been merged successfully!
# The edge 53550 has been merged successfully!
# The edge 53551 has been merged successfully!
# The edge 53552 has been merged successfully!
# The edge 53553 has been merged successfully!
# The edge 53554 has been merged successfully!
# The edge 53555 has been merged successfully!
# The edge 53556 has been merged successfully!
# The edge 53557 has been merged successfully!
# The edge 53558 has been merged successfully!
# The edge 53559 has been merged successfully!
# The edge 53560 has been merged successfully!
# The edge 53561 has been merged successfully!
# The edge 53562 has been merged successfully!
# The edge 53563 has been merged successfully!
# The edge 53564 has been merged successfully!
# The edge 53565 has been merged successfully!
# The edge 53566 has been merged successfully!
# The edge 53567 has been merged successfully!
# The edge 53568 has been merged successfully!
# The edge 53569 has been merged successfully!
# The edge 53570 has been merged successfully!
# The edge 53571 has been merged successfully!
# The edge 53572 has been merged successfully!
# The edge 53573 has been merged successfully!
# The edge 53574 has been merged successfully!
# The edge 53575 has been merged successfully!
# The edge 53576 has been merged successfully!
# The edge 53577 has been merged successfully!
# The edge 53578 has been merged successfully!
# The edge 53579 has been merged successfully!
# The edge 53580 has been merged successfully!
# The edge 53581 has been merged successfully!
# The edge 53582 has been merged successfully!
# The edge 53583 has been merged successfully!
# The edge 53584 has been merged successfully!
# The edge 53585 has been merged successfully!
# The edge 53586 has been merged successfully!
# The edge 53587 has been merged successfully!
# The edge 53588 has been merged successfully!
# The edge 53589 has been merged successfully!
# The edge 53590 has been merged successfully!
# The edge 53591 has been merged successfully!
# The edge 53592 has been merged successfully!
# The edge 53593 has been merged successfully!
# The edge 53594 has been merged successfully!
# The edge 53595 has been merged successfully!
# The edge 53596 has been merged successfully!
# The edge 53597 has been merged successfully!
# The edge 53598 has been merged successfully!
# The edge 53599 has been merged successfully!
# The edge 53600 has been merged successfully!
# The edge 53601 has been merged successfully!
# The edge 53602 has been merged successfully!
# The edge 53603 has been merged successfully!
# The edge 53604 has been merged successfully!
# The edge 53605 has been merged successfully!
# The edge 53606 has been merged successfully!
# The edge 53607 has been merged successfully!
# The edge 53608 has been merged successfully!
# The edge 53609 has been merged successfully!
# The edge 53610 has been merged successfully!
# The edge 53611 has been merged successfully!
# The edge 53612 has been merged successfully!
# The edge 53613 has been merged successfully!
# The edge 53614 has been merged successfully!
# The edge 53615 has been merged successfully!
# The edge 53616 has been merged successfully!
# The edge 53617 has been merged successfully!
# The edge 53618 has been merged successfully!
# The edge 53619 has been merged successfully!
# The edge 53620 has been merged successfully!
# The edge 53621 has been merged successfully!
# The edge 53622 has been merged successfully!
# The edge 53623 has been merged successfully!
# The edge 53624 has been merged successfully!
# The edge 53625 has been merged successfully!
# The edge 53626 has been merged successfully!
# The edge 53627 has been merged successfully!
# The edge 53628 has been merged successfully!
# The edge 53629 has been merged successfully!
# The edge 53630 has been merged successfully!
# The edge 53631 has been merged successfully!
# The edge 53632 has been merged successfully!
# The edge 53633 has been merged successfully!
# The edge 53634 has been merged successfully!
# The edge 53635 has been merged successfully!
# The edge 53636 has been merged successfully!
# The edge 53637 has been merged successfully!
# The edge 53638 has been merged successfully!
# The edge 53639 has been merged successfully!
# The edge 53640 has been merged successfully!
# The edge 53641 has been merged successfully!
# The edge 53642 has been merged successfully!
# The edge 53643 has been merged successfully!
# The edge 53644 has been merged successfully!
# The edge 53645 has been merged successfully!
# The edge 53646 has been merged successfully!
# The edge 53647 has been merged successfully!
# The edge 53648 has been merged successfully!
# The edge 53649 has been merged successfully!
# The edge 53650 has been merged successfully!
# The edge 53651 has been merged successfully!
# The edge 53652 has been merged successfully!
# The edge 53653 has been merged successfully!
# The edge 53654 has been merged successfully!
# The edge 53655 has been merged successfully!
# The edge 53656 has been merged successfully!
# The edge 53657 has been merged successfully!
# The edge 53658 has been merged successfully!
# The edge 53659 has been merged successfully!
# The edge 53660 has been merged successfully!
# The edge 53661 has been merged successfully!
# The edge 53662 has been merged successfully!
# The edge 53663 has been merged successfully!
# The edge 53664 has been merged successfully!
# The edge 53665 has been merged successfully!
# The edge 53666 has been merged successfully!
# The edge 53667 has been merged successfully!
# The edge 53668 has been merged successfully!
# The edge 53669 has been merged successfully!
# The edge 53670 has been merged successfully!
# The edge 53671 has been merged successfully!
# The edge 53672 has been merged successfully!
# The edge 53673 has been merged successfully!
# The edge 53674 has been merged successfully!
# The edge 53675 has been merged successfully!
# The edge 53676 has been merged successfully!
# The edge 53677 has been merged successfully!
# The edge 53678 has been merged successfully!
# The edge 53679 has been merged successfully!
# The edge 53680 has been merged successfully!
# The edge 53681 has been merged successfully!
# The edge 53682 has been merged successfully!
# The edge 53683 has been merged successfully!
# The edge 53684 has been merged successfully!
# The edge 53685 has been merged successfully!
# The edge 53686 has been merged successfully!
# The edge 53687 has been merged successfully!
# The edge 53688 has been merged successfully!
# The edge 53689 has been merged successfully!
# The edge 53690 has been merged successfully!
# The edge 53691 has been merged successfully!
# The edge 53692 has been merged successfully!
# The edge 53693 has been merged successfully!
# The edge 53694 has been merged successfully!
# The edge 53695 has been merged successfully!
# The edge 53696 has been merged successfully!
# The edge 53697 has been merged successfully!
# The edge 53698 has been merged successfully!
# The edge 53699 has been merged successfully!
# The edge 53700 has been merged successfully!
# The edge 53701 has been merged successfully!
# The edge 53702 has been merged successfully!
# The edge 53703 has been merged successfully!
# The edge 53704 has been merged successfully!
# The edge 53705 has been merged successfully!
# The edge 53706 has been merged successfully!
# The edge 53707 has been merged successfully!
# The edge 53708 has been merged successfully!
# The edge 53709 has been merged successfully!
# The edge 53710 has been merged successfully!
# The edge 53711 has been merged successfully!
# The edge 53712 has been merged successfully!
# The edge 53713 has been merged successfully!
# The edge 53714 has been merged successfully!
# The edge 53715 has been merged successfully!
# The edge 53716 has been merged successfully!
# The edge 53717 has been merged successfully!
# The edge 53718 has been merged successfully!
# The edge 53719 has been merged successfully!
# The edge 53720 has been merged successfully!
# The edge 53721 has been merged successfully!
# The edge 53722 has been merged successfully!
# The edge 53723 has been merged successfully!
# The edge 53724 has been merged successfully!
# The edge 53725 has been merged successfully!
# The edge 53726 has been merged successfully!
# Row 53727 has a MultiLineString; using the first LineString component.
# The edge 53728 has been merged successfully!
# The edge 53729 has been merged successfully!
# The edge 53730 has been merged successfully!
# The edge 53731 has been merged successfully!
# The edge 53732 has been merged successfully!
# The edge 53733 has been merged successfully!
# The edge 53734 has been merged successfully!
# The edge 53735 has been merged successfully!
# The edge 53736 has been merged successfully!
# The edge 53737 has been merged successfully!
# The edge 53738 has been merged successfully!
# The edge 53739 has been merged successfully!
# The edge 53740 has been merged successfully!
# The edge 53741 has been merged successfully!
# The edge 53742 has been merged successfully!
# The edge 53743 has been merged successfully!
# The edge 53744 has been merged successfully!
# The edge 53745 has been merged successfully!
# The edge 53746 has been merged successfully!
# The edge 53747 has been merged successfully!
# The edge 53748 has been merged successfully!
# The edge 53749 has been merged successfully!
# The edge 53750 has been merged successfully!
# The edge 53751 has been merged successfully!
# The edge 53752 has been merged successfully!
# The edge 53753 has been merged successfully!
# The edge 53754 has been merged successfully!
# The edge 53755 has been merged successfully!
# The edge 53756 has been merged successfully!
# The edge 53757 has been merged successfully!
# The edge 53758 has been merged successfully!
# The edge 53759 has been merged successfully!
# The edge 53760 has been merged successfully!
# The edge 53761 has been merged successfully!
# The edge 53762 has been merged successfully!
# The edge 53763 has been merged successfully!
# The edge 53764 has been merged successfully!
# The edge 53765 has been merged successfully!
# The edge 53766 has been merged successfully!
# The edge 53767 has been merged successfully!
# The edge 53768 has been merged successfully!
# The edge 53769 has been merged successfully!
# The edge 53770 has been merged successfully!
# The edge 53771 has been merged successfully!
# The edge 53772 has been merged successfully!
# Row 53773 has a MultiLineString; using the first LineString component.
# The edge 53774 has been merged successfully!
# The edge 53775 has been merged successfully!
# The edge 53776 has been merged successfully!
# The edge 53777 has been merged successfully!
# The edge 53778 has been merged successfully!
# The edge 53779 has been merged successfully!
# The edge 53780 has been merged successfully!
# The edge 53781 has been merged successfully!
# The edge 53782 has been merged successfully!
# The edge 53783 has been merged successfully!
# The edge 53784 has been merged successfully!
# The edge 53785 has been merged successfully!
# The edge 53786 has been merged successfully!
# The edge 53787 has been merged successfully!
# The edge 53788 has been merged successfully!
# The edge 53789 has been merged successfully!
# The edge 53790 has been merged successfully!
# The edge 53791 has been merged successfully!
# The edge 53792 has been merged successfully!
# The edge 53793 has been merged successfully!
# The edge 53794 has been merged successfully!
# The edge 53795 has been merged successfully!
# The edge 53796 has been merged successfully!
# The edge 53797 has been merged successfully!
# The edge 53798 has been merged successfully!
# The edge 53799 has been merged successfully!
# The edge 53800 has been merged successfully!
# The edge 53801 has been merged successfully!
# The edge 53802 has been merged successfully!
# The edge 53803 has been merged successfully!
# The edge 53804 has been merged successfully!
# The edge 53805 has been merged successfully!
# The edge 53806 has been merged successfully!
# The edge 53807 has been merged successfully!
# The edge 53808 has been merged successfully!
# The edge 53809 has been merged successfully!
# The edge 53810 has been merged successfully!
# The edge 53811 has been merged successfully!
# The edge 53812 has been merged successfully!
# The edge 53813 has been merged successfully!
# The edge 53814 has been merged successfully!
# The edge 53815 has been merged successfully!
# The edge 53816 has been merged successfully!
# The edge 53817 has been merged successfully!
# The edge 53818 has been merged successfully!
# The edge 53819 has been merged successfully!
# The edge 53820 has been merged successfully!
# The edge 53821 has been merged successfully!
# The edge 53822 has been merged successfully!
# The edge 53823 has been merged successfully!
# The edge 53824 has been merged successfully!
# The edge 53825 has been merged successfully!
# The edge 53826 has been merged successfully!
# The nodes of the source edgee has been created successfully!

# %%
#Local networks

edges_version_2_path = source_edges_path_updated
edges_version_2 = gpd.read_file(edges_version_2_path) #Calling rectified edges
edges_version_2.reset_index(drop=True, inplace=True); edges_version_2 = edges_version_2.drop(columns=['start_node', 'end_node']) #Resetting source edge's index and removing unnecessary columns

def convert_multilinestring_to_linestring(geom):
    """
    Converts a MultiLineString geometry into a single LineString.
    If the geometry is already a LineString, it returns it unchanged.
    """
    if isinstance(geom, MultiLineString):
        # Collect all coordinates from the MultiLineString
        coords = []
        for part in geom.geoms:
            coords.extend(part.coords)
        # Create a new LineString from the concatenated coordinates
        return LineString(coords)
    else:
        # If it's already a LineString, return it as is
        return geom
    
edges_version_2['geometry'] = edges_version_2['geometry'].apply(convert_multilinestring_to_linestring) # Apply the conversion to an entire GeoDataFrame column

NPA_shape = subdivision_dataset

buffer_list_mile = [0.1,0.25,0.5,0.75,1.0]
buffer_distance_feet = []

for buffer_mile in buffer_list_mile:
    buffer_distance_feet.append(buffer_mile * 5280)
    buffer_mile_name = str(buffer_mile).replace(".", "")
    NPA_shape['geometry'] = NPA_shape['geometry'].apply(lambda geom: geom.buffer(buffer_mile * 5280)) #Applying buffer operation to the geometry column


    for idx, polygon in NPA_shape.iterrows():
        
        edge_NPA = edges_version_2[edges_version_2.intersects(polygon.geometry)]     # Find edges intersecting with the buffered polygon
    
        #Extracting nodes at the end of each edge
    
        endpoint_coords = []     # Create an empty list to store the endpoint coordinates
        node_id = 0     # Iterate through the street network and find endpoint coordinates
        node_id_mapping = {}
    
        # Iterate through the street network and find endpoint coordinates
        for index, row in edge_NPA.iterrows():
            geometry = row['geometry']
    
            # Check if the geometry is single-part or multi-part
            if geometry.geom_type == 'LineString':
                # Single-part geometry, safe to access coords directly
                start_point = Point(geometry.coords[0])
                end_point = Point(geometry.coords[-1])
            elif geometry.geom_type == 'MultiLineString':
                # Multi-part geometry: get the start point of the first part and the end point of the last part
                first_part = geometry.geoms[0]  # First LineString
                last_part = geometry.geoms[-1]  # Last LineString
                start_point = Point(first_part.coords[0])  # Start of first part
                end_point = Point(last_part.coords[-1])
    
            # Add start and end node ids to the edge GeoDataFrame
            if start_point.coords[0] not in node_id_mapping:
                endpoint_coords.append({'id': node_id, 'geometry': start_point})
                node_id_mapping[start_point.coords[0]] = node_id
                start_node_id = node_id
                node_id += 1
            else:
                start_node_id = node_id_mapping[start_point.coords[0]]
    
            if end_point.coords[0] not in node_id_mapping:
                endpoint_coords.append({'id': node_id, 'geometry': end_point})
                node_id_mapping[end_point.coords[0]] = node_id
                end_node_id = node_id
                node_id += 1
            else:
                end_node_id = node_id_mapping[end_point.coords[0]]
    
            edge_NPA.at[index, 'start_node'] = start_node_id
            edge_NPA.at[index, 'end_node'] = end_node_id
               
        # Create a GeoDataFrame from the endpoint coordinates
        nodes_NPA = gpd.GeoDataFrame(endpoint_coords, crs=edge_NPA.crs)
        nodes_NPA['x'] = nodes_NPA['geometry'].x
        nodes_NPA['y'] = nodes_NPA['geometry'].y
        nodes_NPA["osmid"] = nodes_NPA["id"].astype("int")
        nodes_NPA.set_index('id', inplace=True)  # Set 'id' column as index
    
        #indexing NPA edges
        edge_NPA["u"] = edge_NPA["start_node"].astype("int")
        edge_NPA["v"] = edge_NPA["end_node"].astype("int")
        edge_NPA["k"] = range(1, len(edge_NPA) + 1)
        edge_NPA["osmid"] = edge_NPA["k"]
        edge_NPA.set_index(["u","v","k"], inplace=True)
        # print(f"network elements for {idx} has been created successfully!")

        # Define the directory path
        output_dir = os.path.join(source_edges_path, f"local_grpahs/{polygon['subd_id']}_{buffer_mile_name}"); os.makedirs(output_dir, exist_ok=True)

        # Save the GeoDataFrame to a shapefile
        nodes_version_3_path = os.path.join(output_dir, f"nodes_version_3.shp")
        edges_version_3_path = os.path.join(output_dir, f"edges_version_3.shp")
        nodes_NPA.to_file(nodes_version_3_path); edge_NPA.to_file(edges_version_3_path)
        print(f"local network has been created for the local graph {polygon['subd_id']}_{buffer_mile_name}")

    NPA_shape = subdivision_dataset #reseting the subdivision dataset
# Out:
# local network has been created for the local graph 95.0_01
# local network has been created for the local graph 147.0_01
# local network has been created for the local graph 185.0_01
# local network has been created for the local graph 200.0_01
# local network has been created for the local graph 212.0_01
# local network has been created for the local graph 243.0_01
# local network has been created for the local graph 249.0_01
# local network has been created for the local graph 261.0_01
# local network has been created for the local graph 272.0_01
# local network has been created for the local graph 302.0_01
# local network has been created for the local graph 320.0_01
# local network has been created for the local graph 328.0_01
# local network has been created for the local graph 353.0_01
# local network has been created for the local graph 364.0_01
# local network has been created for the local graph 367.0_01
# local network has been created for the local graph 405.0_01
# local network has been created for the local graph 416.0_01
# local network has been created for the local graph 485.0_01
# local network has been created for the local graph 520.0_01
# local network has been created for the local graph 526.0_01
# local network has been created for the local graph 548.0_01
# local network has been created for the local graph 549.0_01
# local network has been created for the local graph 550.0_01
# local network has been created for the local graph 551.0_01
# local network has been created for the local graph 552.0_01
# local network has been created for the local graph 553.0_01
# local network has been created for the local graph 554.0_01
# local network has been created for the local graph 555.0_01
# local network has been created for the local graph 557.0_01
# local network has been created for the local graph 603.0_01
# local network has been created for the local graph 629.0_01
# local network has been created for the local graph 732.0_01
# local network has been created for the local graph 935.0_01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 101
#      99     nodes_version_3_path = os.path.join(output_dir, f"nodes_version_3.shp")
#     100     edges_version_3_path = os.path.join(output_dir, f"edges_version_3.shp")
# --> 101     nodes_NPA.to_file(nodes_version_3_path); edge_NPA.to_file(edges_version_3_path)
#     102     print(f"local network has been created for the local graph {polygon['subd_id']}_{buffer_mile_name}")
#     104 NPA_shape = subdivision_dataset #reseting the subdivision dataset
#
# File ~\AppData\Roaming\Python\Python310\site-packages\geopandas\geodataframe.py:1536, in GeoDataFrame.to_file(self, filename, driver, schema, index, **kwargs)
#    1441 """Write the ``GeoDataFrame`` to a file.
#    1442
#    1443 By default, an ESRI shapefile is written, but any OGR data source
#    (...)
#    1532
#    1533 """
#    1534 from geopandas.io.file import _to_file
# -> 1536 _to_file(self, filename, driver, schema, index, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\geopandas\io\file.py:686, in _to_file(df, filename, driver, schema, index, mode, crs, engine, metadata, **kwargs)
#     683     raise ValueError(f"'mode' should be one of 'w' or 'a', got '{mode}' instead")
#     685 if engine == "pyogrio":
# --> 686     _to_file_pyogrio(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#     687 elif engine == "fiona":
#     688     _to_file_fiona(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\geopandas\io\file.py:748, in _to_file_pyogrio(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#     745 if not df.columns.is_unique:
#     746     raise ValueError("GeoDataFrame cannot contain duplicated column names.")
# --> 748 pyogrio.write_dataframe(df, filename, driver=driver, metadata=metadata, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyogrio\geopandas.py:654, in write_dataframe(df, path, layer, driver, encoding, geometry_type, promote_to_multi, nan_as_null, append, use_arrow, dataset_metadata, layer_metadata, metadata, dataset_options, layer_options, **kwargs)
#     651 if geometry_column is not None:
#     652     geometry = to_wkb(geometry.values)
# --> 654 write(
#     655     path,
#     656     layer=layer,
#     657     driver=driver,
#     658     geometry=geometry,
#     659     field_data=field_data,
#     660     field_mask=field_mask,
#     661     fields=fields,
#     662     crs=crs,
#     663     geometry_type=geometry_type,
#     664     encoding=encoding,
#     665     promote_to_multi=promote_to_multi,
#     666     nan_as_null=nan_as_null,
#     667     append=append,
#     668     dataset_metadata=dataset_metadata,
#     669     layer_metadata=layer_metadata,
#     670     metadata=metadata,
#     671     dataset_options=dataset_options,
#     672     layer_options=layer_options,
#     673     gdal_tz_offsets=gdal_tz_offsets,
#     674     **kwargs,
#     675 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyogrio\raw.py:709, in write(path, geometry, field_data, fields, field_mask, layer, driver, geometry_type, crs, encoding, promote_to_multi, nan_as_null, append, dataset_metadata, layer_metadata, metadata, dataset_options, layer_options, gdal_tz_offsets, **kwargs)
#     704 # preprocess kwargs and split in dataset and layer creation options
#     705 dataset_kwargs, layer_kwargs = _preprocess_options_kwargs(
#     706     driver, dataset_options, layer_options, kwargs
#     707 )
# --> 709 ogr_write(
#     710     path,
#     711     layer=layer,
#     712     driver=driver,
#     713     geometry=geometry,
#     714     geometry_type=geometry_type,
#     715     field_data=field_data,
#     716     field_mask=field_mask,
#     717     fields=fields,
#     718     crs=crs,
#     719     encoding=encoding,
#     720     promote_to_multi=promote_to_multi,
#     721     nan_as_null=nan_as_null,
#     722     append=append,
#     723     dataset_metadata=dataset_metadata,
#     724     layer_metadata=layer_metadata,
#     725     dataset_kwargs=dataset_kwargs,
#     726     layer_kwargs=layer_kwargs,
#     727     gdal_tz_offsets=gdal_tz_offsets,
#     728 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyogrio\_io.pyx:2495, in pyogrio._io.ogr_write()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py:1476, in Logger.info(self, msg, *args, **kwargs)
#    1467 def info(self, msg, *args, **kwargs):
#    1468     """
#    1469     Log 'msg % args' with severity 'INFO'.
#    1470
#    (...)
#    1474     logger.info("Houston, we have a %s", "interesting problem", exc_info=1)
#    1475     """
# -> 1476     if self.isEnabledFor(INFO):
#    1477         self._log(INFO, msg, args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py:1724, in Logger.isEnabledFor(self, level)
#    1721         logger = logger.parent
#    1722     return NOTSET
# -> 1724 def isEnabledFor(self, level):
#    1725     """
#    1726     Is this logger enabled for level 'level'?
#    1727     """
#    1728     if self.disabled:
#
# KeyboardInterrupt:

# %%
#extracting the largest network
for idx, polygon in NPA_shape.iterrows():

    output_dir = os.path.join(source_edges_path, f"local_grpahs/{polygon['subd_id']}_{buffer_mile_name}")
    nodes_version_3_path = os.path.join(output_dir, f"nodes_version_3.shp")
    edges_version_3_path = os.path.join(output_dir, f"edges_version_3.shp")
    edge_version_3 = gpd.read_file(edges_version_3_path)
    nodes_version_3 = gpd.read_file(nodes_version_3_path)


    # remove any unconnected node and edge to the main network
    G = Graph()

    # Add nodes from nodes GeoDataFrame
    for node_id, geometry in zip(nodes_version_3['osmid'], nodes_version_3['geometry']):
        G.add_node(node_id, pos=(geometry.x, geometry.y))  # Store node positions if needed

    # Add edges from edges GeoDataFrame
    for source, target, geometry in zip(edge_version_3['start_node'], edge_version_3['end_node'], edge_version_3['geometry']):
        G.add_edge(source, target, geometry=geometry)

    #getting the largest part of the network
    components = list(connected_components(G))
    largest_component = max(components, key=len)
    G_main = G.subgraph(largest_component).copy()

    # appending the overpasses and underpasses to the main network
    remaining_components = [component for component in components if component != largest_component] # Store the remaining components (all except the largest)
    # Convert edges of the largest component to a GeoDataFrame for spatial operations
    edges_main_gdf = edge_version_3[edge_version_3['start_node'].isin(largest_component) & edge_version_3['end_node'].isin(largest_component)]

    # Loop through each remaining component
    for component in remaining_components:
        # Extract edges of the current component
        edges_component_gdf = edge_version_3[(edge_version_3['start_node'].isin(component)) & (edge_version_3['end_node'].isin(component))]
        # Check if any edges intersect with the largest component's edges
        if edges_component_gdf.geometry.intersects(edges_main_gdf.geometry.unary_union).any():
            # If they intersect, add this component to the largest component
            for node in component:
                G_main.add_node(node)  # Add nodes of the component
            for _, edge in edges_component_gdf.iterrows():
                G_main.add_edge(edge['start_node'], edge['end_node'], geometry=edge['geometry'])  # Add edges


    # Get the nodes that are part of the main component
    main_nodes = list(G_main.nodes())
    # Filter nodes_gdf to keep only nodes in the main component
    nodes_gdf_main = nodes_version_3[nodes_version_3['osmid'].isin(main_nodes)].copy()

    # Export the edeges of G_main to GeoDataFrame
    main_edges = list(G_main.edges(data=True))  # Get edges with data (geometry)
    if main_edges:  # Check if there are edges in G_main
        # Create a list to hold edge data
        edges_data = []

        for (start, end, data) in main_edges:
            edges_data.append({
                'start_node': start,
                'end_node': end,
                'geometry': data['geometry']
            })

        # Create a GeoDataFrame from the list of edges data
        gdf_edges_main = gpd.GeoDataFrame(edges_data)

        # Set CRS if known
        gdf_edges_main.set_crs(edge_version_3.crs, inplace=True)

        # Optionally save the GeoDataFrame to a shapefile
        edge_version_4_path = os.path.join(os.path.dirname(edges_version_3_path), f"edges_version_4.shp")
        gdf_edges_main.to_file(edge_version_4_path)
        print("Saved edges of the largest component to shapefile.")
    else:
        print("G_main has no edges to convert to GeoDataFrame.")

    # Export the nodes of G_main to GeoDataFrame
    main_nodes = list(G_main.nodes(data=True))  # Get nodes with data (geometry)
    if main_nodes:  # Check if there are nodes in G_main
        # Create a list to hold node data
        nodes_data = []

        for node, data in main_nodes:
            # Get the geometry for the node
            node_geometry = nodes_version_3[nodes_version_3['osmid'] == node]['geometry'].values[0]
            nodes_data.append({
                'osmid': node,
                'geometry': node_geometry
            })

        # Create a GeoDataFrame from the list of nodes data
        gdf_nodes_main = gpd.GeoDataFrame(nodes_data)

        # Set CRS if known
        gdf_nodes_main.set_crs(nodes_version_3.crs, inplace=True)

        # Optionally save the GeoDataFrame to a shapefile
        nodes_version_4_path = os.path.join(os.path.dirname(nodes_version_3_path), f"nodes_version_4.shp")
        gdf_nodes_main.to_file(nodes_version_4_path)
        print("Saved nodes of the largest component to shapefile.")
    else:
        print("G_main has no nodes to convert to GeoDataFrame.")
# Out:
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# Saved edges of the largest component to shapefile.
# Saved nodes of the largest component to shapefile.
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In [15], line 8
#       6 nodes_version_3_path = os.path.join(output_dir, f"nodes_version_3.shp")
#       7 edges_version_3_path = os.path.join(output_dir, f"edges_version_3.shp")
# ----> 8 edge_version_3 = gpd.read_file(edges_version_3_path)
#       9 nodes_version_3 = gpd.read_file(nodes_version_3_path)
#      12 # remove any unconnected node and edge to the main network
#
# File ~\AppData\Roaming\Python\Python310\site-packages\geopandas\io\file.py:294, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     291             from_bytes = True
#     293 if engine == "pyogrio":
# --> 294     return _read_file_pyogrio(
#     295         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     296     )
#     298 elif engine == "fiona":
#     299     if pd.api.types.is_file_like(filename):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\geopandas\io\file.py:547, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     538     warnings.warn(
#     539         "The 'include_fields' and 'ignore_fields' keywords are deprecated, and "
#     540         "will be removed in a future release. You can use the 'columns' keyword "
#    (...)
#     543         stacklevel=3,
#     544     )
#     545     kwargs["columns"] = kwargs.pop("include_fields")
# --> 547 return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyogrio\geopandas.py:261, in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, **kwargs)
#     256 if not use_arrow:
#     257     # For arrow, datetimes are read as is.
#     258     # For numpy IO, datetimes are read as string values to preserve timezone info
#     259     # as numpy does not directly support timezones.
#     260     kwargs["datetime_as_string"] = True
# --> 261 result = read_func(
#     262     path_or_buffer,
#     263     layer=layer,
#     264     encoding=encoding,
#     265     columns=columns,
#     266     read_geometry=read_geometry,
#     267     force_2d=gdal_force_2d,
#     268     skip_features=skip_features,
#     269     max_features=max_features,
#     270     where=where,
#     271     bbox=bbox,
#     272     mask=mask,
#     273     fids=fids,
#     274     sql=sql,
#     275     sql_dialect=sql_dialect,
#     276     return_fids=fid_as_index,
#     277     **kwargs,
#     278 )
#     280 if use_arrow:
#     281     meta, table = result
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyogrio\raw.py:196, in read(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, datetime_as_string, **kwargs)
#      56 """Read OGR data source into numpy arrays.
#      57
#      58 IMPORTANT: non-linear geometry types (e.g., MultiSurface) are converted
#    (...)
#     191
#     192 """
#     194 dataset_kwargs = _preprocess_options_key_value(kwargs) if kwargs else {}
# --> 196 return ogr_read(
#     197     get_vsi_path_or_buffer(path_or_buffer),
#     198     layer=layer,
#     199     encoding=encoding,
#     200     columns=columns,
#     201     read_geometry=read_geometry,
#     202     force_2d=force_2d,
#     203     skip_features=skip_features,
#     204     max_features=max_features or 0,
#     205     where=where,
#     206     bbox=bbox,
#     207     mask=_mask_to_wkb(mask),
#     208     fids=fids,
#     209     sql=sql,
#     210     sql_dialect=sql_dialect,
#     211     return_fids=return_fids,
#     212     dataset_kwargs=dataset_kwargs,
#     213     datetime_as_string=datetime_as_string,
#     214 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyogrio\_io.pyx:1239, in pyogrio._io.ogr_read()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyogrio\_io.pyx:219, in pyogrio._io.ogr_open()
#
# DataSourceError: ../../../Data/Original_dataset/Archive/centerlinemeck_10_8/local_grpahs/950.0_01\edges_version_3.shp: No such file or directory

# %%
for buffer_mile in buffer_list_mile:
    
    buffer_mile_name = str(buffer_mile).replace(".", "")

    for idx, polygon in NPA_shape.iterrows():
        
        output_dir = os.path.join(source_edges_path, f"local_grpahs/{polygon['id']}_{buffer_mile_name}")
        edges_version_4_1_path = os.path.join(output_dir, f"edges_version_4_1.shp")
        edges_version_4_1 = gpd.read_file(edges_version_4_1_path,index=False); edges_version_4_1 = edges_version_4_1.set_crs(crs=NPA_shape.crs)
        nodes_version_4_1_path = os.path.join(output_dir, f"nodes_version_4_1.shp")
        nodes_version_4_1 = gpd.read_file(nodes_version_4_1_path, index=False); nodes_version_4_1 = nodes_version_4_1.set_crs(crs=NPA_shape.crs)
    
        edges_version_4_1["u"] = edges_version_4_1["start_node"].astype("int"); edges_version_4_1["v"] = edges_version_4_1["end_node"].astype("int")
        edges_version_4_1["key"] = range(1, len(edges_version_4_1) + 1)
        edges_version_4_1["osmid"] = edges_version_4_1["key"]
        edges_version_4_1.set_index(["u","v","key"], inplace=True)
        edges_version_4_1['length'] = edges_version_4_1['geometry'].length
        
        # Initialize a directed or undirected graph using nx
        G = nx.Graph()
        
        # Add nodes with attributes
        for _, row in nodes_version_4_1.iterrows():
            node_id = row['osmid']  # Adjust column name if needed
            G.add_node(node_id, **row.to_dict())
    
        # Add edges with attributes
        for _, row in edges_version_4_1.iterrows():
            start_node = int(row['start_node'])  # Adjust column names if needed
            end_node = int(row['end_node'])
            edge_data = {
                'length': row['geometry'].length,
                # Add other edge attributes if necessary
            }
            G.add_edge(start_node, end_node, **edge_data, weight = row['geometry'].length)
    
        #converting to undirected graph
        G = G.to_undirected()
        
        #area of interest
        temp_gdf = gpd.GeoDataFrame(geometry=[polygon.geometry], crs=NPA_shape.crs)
        temp_gdf['geometry'] = temp_gdf['geometry'].apply(lambda geom: geom.buffer(buffer_mile * 5280))
        temp_buffer = temp_gdf["geometry"].area[0]
        area_acre = temp_buffer / 43560
    
    
        # intersection density
        intersections = [node for node in G.nodes if G.degree(node) >= 3]; num_intersections = len(intersections); intersection_density = num_intersections / area_acre
        if "int_den" + buffer_mile_name not in NPA_shape.columns:
            NPA_shape["int_den" + buffer_mile_name] = 0
        NPA_shape.loc[idx, "int_den"+ buffer_mile_name] = intersection_density
        
        # avg. node degree
        average_node_degree = sum(dict(G.degree()).values()) / G.number_of_nodes(); NPA_shape.loc[idx, "nd_deg" + buffer_mile_name] = average_node_degree
